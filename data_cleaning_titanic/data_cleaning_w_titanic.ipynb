# %% [markdown]
# # 1. 데이터 확인하기

# %%
import pandas as pd

# %%
titanic_df = pd.read_csv('/aiffel/data/titanic.csv')

# %%
titanic_df
# Out:
#      Pclass                                               Name   Gendr   Age  \
# 0         3                            Braund, Mr. Owen Harris    male  22.0
# 1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2         3                             Heikkinen, Miss. Laina  female  26.0
# 3         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   NaN
# 4         3                           Allen, Mr. William Henry    male  35.0
# ..      ...                                                ...     ...   ...
# 880       2                              Montvila, Rev. Juozas    male  27.0
# 881       1                       Graham, Miss. Margaret Edith  female  19.0
# 882       3           Johnston, Miss. Catherine Helen "Carrie"  female  28.0
# 883       1                              Behr, Mr. Karl Howell    male  26.0
# 884       3                                Dooley, Mr. Patrick    male  32.0
#
# ...

# %%
titanic_df.head()
# Out:
#    Pclass                                               Name   Gendr   Age  \
# 0       3                            Braund, Mr. Owen Harris    male  22.0
# 1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2       3                             Heikkinen, Miss. Laina  female  26.0
# 3       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   NaN
# 4       3                           Allen, Mr. William Henry    male  35.0
#
#    SibSp  Parch            Ticket Embarked  Survived ticket_date
# 0      1      0         A/5 21171        S         0  1912-01-12
# 1      1      0          PC 17599        C         1  1912-03-29
# 2      0      0  STON/O2. 3101282        S         1  1912-02-23
# 3      1      0            113803        S         1  1912-03-28
# 4      0      0            373450        S         0  1912-04-03

# %%
# DataFrame 또는 Series 객체의 끝에서부터 지정된 수의 행을 반환
titanic_df.tail()
# Out:
#      Pclass                                      Name   Gendr   Age  SibSp  \
# 880       2                     Montvila, Rev. Juozas    male  27.0      0
# 881       1              Graham, Miss. Margaret Edith  female  19.0      0
# 882       3  Johnston, Miss. Catherine Helen "Carrie"  female  28.0      1
# 883       1                     Behr, Mr. Karl Howell    male  26.0      0
# 884       3                       Dooley, Mr. Patrick    male  32.0      0
#
#      Parch      Ticket Embarked  Survived ticket_date
# 880      0      211536        S         0  1912-01-29
# 881      0      112053        S         1  1912-03-30
# 882      2  W./C. 6607        S         0  1912-04-07
# 883      0      111369        C         1  1912-03-01
# 884      0      370376        Q         0  1912-03-05

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 885 entries, 0 to 884
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Pclass       885 non-null    int64
#  1   Name         885 non-null    object
#  2   Gendr        885 non-null    object
#  3   Age          879 non-null    float64
#  4   SibSp        885 non-null    int64
#  5   Parch        885 non-null    int64
#  6   Ticket       885 non-null    object
#  7   Embarked     883 non-null    object
#  8   Survived     885 non-null    int64
#  9   ticket_date  885 non-null    object
# dtypes: float64(1), int64(4), object(5)
# memory usage: 69.3+ KB

# %%
#DataFrame 또는 Series 객체에 대한 요약 통계를 제공
titanic_df.describe()
# Out:
#            Pclass         Age       SibSp       Parch    Survived
# count  885.000000  879.000000  885.000000  885.000000  885.000000
# mean     2.311864   29.679181    0.525424    0.377401    0.377401
# std      0.836069   13.559664    1.109746    0.805768    0.485011
# min      1.000000    1.000000    0.000000    0.000000    0.000000
# 25%      2.000000   22.000000    0.000000    0.000000    0.000000
# 50%      3.000000   28.000000    0.000000    0.000000    0.000000
# 75%      3.000000   35.000000    1.000000    0.000000    1.000000
# max      3.000000  145.000000    8.000000    6.000000    1.000000

# %%
# Pandas Series 형태
titanic_df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 880                                Montvila, Rev. Juozas
# 881                         Graham, Miss. Margaret Edith
# 882             Johnston, Miss. Catherine Helen "Carrie"
# 883                                Behr, Mr. Karl Howell
# 884                                  Dooley, Mr. Patrick
# Name: Name, Length: 885, dtype: object

# %%
# DataFrame 형태
titanic_df[['Name', 'Age']]
# Out:
#                                                   Name   Age
# 0                              Braund, Mr. Owen Harris  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                               Heikkinen, Miss. Laina  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)   NaN
# 4                             Allen, Mr. William Henry  35.0
# ..                                                 ...   ...
# 880                              Montvila, Rev. Juozas  27.0
# 881                       Graham, Miss. Margaret Edith  19.0
# 882           Johnston, Miss. Catherine Helen "Carrie"  28.0
# 883                              Behr, Mr. Karl Howell  26.0
# 884                                Dooley, Mr. Patrick  32.0
#
# [885 rows x 2 columns]

# %%
# Series -> DataFrame
pd.DataFrame(titanic_df['Name'])
# Out:
#                                                   Name
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# ..                                                 ...
# 880                              Montvila, Rev. Juozas
# 881                       Graham, Miss. Margaret Edith
# 882           Johnston, Miss. Catherine Helen "Carrie"
# 883                              Behr, Mr. Karl Howell
# 884                                Dooley, Mr. Patrick
#
# [885 rows x 1 columns]

# %%
# Series -> DataFrame -> Series (인덱싱 필요)
# 실제로 사용할 일은 없을 것
pd.Series(pd.DataFrame(titanic_df['Name'])['Name'])
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 880                                Montvila, Rev. Juozas
# 881                         Graham, Miss. Margaret Edith
# 882             Johnston, Miss. Catherine Helen "Carrie"
# 883                                Behr, Mr. Karl Howell
# 884                                  Dooley, Mr. Patrick
# Name: Name, Length: 885, dtype: object

# %%
import numpy as np

# 컴퓨터 입장에서 데이터를 다룰 때 용이
# pandas에 비해 훨씬 빠르고 포맷이 단순하여 연산이 용이

# %%
np.array(titanic_df)
# Out:
# array([[3, 'Braund, Mr. Owen Harris', 'male', ..., 'S', 0, '1912-01-12'],
#        [1, 'Cumings, Mrs. John Bradley (Florence Briggs Thayer)',
#         'female', ..., 'C', 1, '1912-03-29'],
#        [3, 'Heikkinen, Miss. Laina', 'female', ..., 'S', 1, '1912-02-23'],
#        ...,
#        [3, 'Johnston, Miss. Catherine Helen "Carrie"', 'female', ...,
#         'S', 0, '1912-04-07'],
#        [1, 'Behr, Mr. Karl Howell', 'male', ..., 'C', 1, '1912-03-01'],
#        [3, 'Dooley, Mr. Patrick', 'male', ..., 'Q', 0, '1912-03-05']],
#       dtype=object)

# %% [markdown]
# # 2. 불필요한 컬럼 삭제 (Dropping columns), 누락된 결측치 처리 (Missing values)

# %%
# 중복 데이터 처리 부분에서 활용
titanic_df[titanic_df.duplicated()]
# Out:
#      Pclass                           Name   Gendr   Age  SibSp  Parch  \
# 25        3  Palsson, Miss. Torborg Danira  female   8.0      3      1
# 632       3             Skoog, Miss. Mabel  female   9.0      3      2
# 714       1  Endres, Miss. Caroline Louise  female  38.0      0      0
#
#        Ticket Embarked  Survived ticket_date
# 25     349909        S         0  1912-03-14
# 632    347088        S         0  1912-03-16
# 714  PC 17757        C         1  1912-03-14

# %%
# 중복 데이터 처리 부분에서 활용
titanic_df[titanic_df['Name'] == 'Palsson, Miss. Torborg Danira']
# Out:
#     Pclass                           Name   Gendr  Age  SibSp  Parch  Ticket  \
# 24       3  Palsson, Miss. Torborg Danira  female  8.0      3      1  349909
# 25       3  Palsson, Miss. Torborg Danira  female  8.0      3      1  349909
#
#    Embarked  Survived ticket_date
# 24        S         0  1912-03-14
# 25        S         0  1912-03-14

# %%
# 중복 데이터 처리 부분에서 활용
titanic_df = titanic_df.drop_duplicates()

# %% [markdown]
# ### 'Name' 컬럼 제거

# %%
# 파라미터 axis=축 -> 기본값 0
# 컬럼 단위로 찾기 위해 axis=1로 지정

titanic_df.drop('Name', axis = 1)

# 컬럼 2개 이상 지정 시, 리스트로 묶어줘야 한다.
# titanic_df.drop(['Pclass', 'Age'], axis = 1)

# drop된 결과만 보여줄 뿐이지, 원래 데이터에 덮어씌워지는 것은 아니다.
# Out:
#      Pclass   Gendr   Age  SibSp  Parch            Ticket Embarked  Survived  \
# 0         3    male  22.0      1      0         A/5 21171        S         0
# 1         1  female  38.0      1      0          PC 17599        C         1
# 2         3  female  26.0      0      0  STON/O2. 3101282        S         1
# 3         1  female   NaN      1      0            113803        S         1
# 4         3    male  35.0      0      0            373450        S         0
# ..      ...     ...   ...    ...    ...               ...      ...       ...
# 880       2    male  27.0      0      0            211536        S         0
# 881       1  female  19.0      0      0            112053        S         1
# 882       3  female  28.0      1      2        W./C. 6607        S         0
# 883       1    male  26.0      0      0            111369        C         1
# 884       3    male  32.0      0      0            370376        Q         0
#
#     ticket_date
# 0    1912-01-12
# ...

# %%
# 원본 데이터를 완전히 업데이트하려면
# 방법 1
# titanic_df = titanic_df.drop('Name', axis = 1)

# %%
# 방법 2
# iplace 기본값은 False
titanic_df.drop('Name', axis = 1, inplace = True)

# %%
titanic_df.head()
# Out:
#    Pclass   Gendr   Age  SibSp  Parch            Ticket Embarked  Survived  \
# 0       3    male  22.0      1      0         A/5 21171        S         0
# 1       1  female  38.0      1      0          PC 17599        C         1
# 2       3  female  26.0      0      0  STON/O2. 3101282        S         1
# 3       1  female   NaN      1      0            113803        S         1
# 4       3    male  35.0      0      0            373450        S         0
#
#   ticket_date
# 0  1912-01-12
# 1  1912-03-29
# 2  1912-02-23
# 3  1912-03-28
# 4  1912-04-03

# %%
# 인덱스(행) 이름 변경해 보기

# temp = titanic_df.head().copy()
# temp.index = ['a', 'b', 'c', 'd', 'e']

# %% [markdown]
# ### 결측치 처리하기

# %% [markdown]
# loc vs iloc

# %%
# isna(): 결측치 확인하는 pandas 메소드
titanic_df.isna()
# Out:
#      Pclass  Gendr    Age  SibSp  Parch  Ticket  Embarked  Survived  \
# 0     False  False  False  False  False   False     False     False
# 1     False  False  False  False  False   False     False     False
# 2     False  False  False  False  False   False     False     False
# 3     False  False   True  False  False   False     False     False
# 4     False  False  False  False  False   False     False     False
# ..      ...    ...    ...    ...    ...     ...       ...       ...
# 880   False  False  False  False  False   False     False     False
# 881   False  False  False  False  False   False     False     False
# 882   False  False  False  False  False   False     False     False
# 883   False  False  False  False  False   False     False     False
# 884   False  False  False  False  False   False     False     False
#
#      ticket_date
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
# ..           ...
# 880        False
# ...

# %%
# 각 컬럼별 결측치 개수 확인 - True는 1이므로
titanic_df.isna().sum()
# Out:
# Pclass         0
# Gendr          0
# Age            6
# SibSp          0
# Parch          0
# Ticket         0
# Embarked       2
# Survived       0
# ticket_date    0
# dtype: int64

# %%
# 각 컬럼별 결측치 비율 확인
titanic_df.isna().mean()
# Out:
# Pclass         0.00000
# Gendr          0.00000
# Age            0.00678
# SibSp          0.00000
# Parch          0.00000
# Ticket         0.00000
# Embarked       0.00226
# Survived       0.00000
# ticket_date    0.00000
# dtype: float64

# %%
titanic_df[titanic_df['Age'].isna()]
# Out:
#      Pclass   Gendr  Age  SibSp  Parch           Ticket Embarked  Survived  \
# 3         1  female  NaN      1      0           113803        S         1
# 106       3    male  NaN      0      0           312991        S         1
# 156       3    male  NaN      0      0  SOTON/OQ 392090        S         0
# 185       3  female  NaN      1      0           370365        Q         1
# 213       3    male  NaN      1      0           367229        Q         0
# 241       2    male  NaN      0      0      W./C. 14263        S         0
#
#     ticket_date
# 3    1912-03-28
# 106  1912-01-27
# 156  1912-04-01
# 185  1912-03-25
# 213  1912-02-12
# 241  1912-01-31

# %%
age_na_index = titanic_df[titanic_df['Age'].isna()].index

# %%
age_na_index
# Out:
# Int64Index([3, 106, 156, 185, 213, 241], dtype='int64')

# %%
embarked_na_index = titanic_df[titanic_df['Embarked'].isna()].index
embarked_na_index
# Out:
# Int64Index([15, 322], dtype='int64')

# %%
titanic_df.loc[age_na_index]
# Out:
#      Pclass   Gendr  Age  SibSp  Parch           Ticket Embarked  Survived  \
# 3         1  female  NaN      1      0           113803        S         1
# 106       3    male  NaN      0      0           312991        S         1
# 156       3    male  NaN      0      0  SOTON/OQ 392090        S         0
# 185       3  female  NaN      1      0           370365        Q         1
# 213       3    male  NaN      1      0           367229        Q         0
# 241       2    male  NaN      0      0      W./C. 14263        S         0
#
#     ticket_date
# 3    1912-03-28
# 106  1912-01-27
# 156  1912-04-01
# 185  1912-03-25
# 213  1912-02-12
# 241  1912-01-31

# %%
titanic_df.loc[embarked_na_index]
# Out:
#      Pclass   Gendr   Age  SibSp  Parch    Ticket Embarked  Survived  \
# 15        2  female  55.0      0      0    248706      NaN         1
# 322       3    male  28.0      8      2  CA. 2343      NaN         0
#
#     ticket_date
# 15   1912-03-05
# 322  1912-03-26

# %% [markdown]
# ### NaN 값이 있는 행 제거하기 (결측치 제거)

# %%
len(titanic_df)
# Out:
# 885

# %%
# 방법 1. 노이즈가 끼는 것을 막기 위해 결측치가 있는 모든 행 제거
titanic_df.dropna()

# 데이터의 크기가 충분히 크지 않으면, 정보의 유실이 커지기 때문에 충분히 고려해야 함
# Out:
#      Pclass   Gendr   Age  SibSp  Parch            Ticket Embarked  Survived  \
# 0         3    male  22.0      1      0         A/5 21171        S         0
# 1         1  female  38.0      1      0          PC 17599        C         1
# 2         3  female  26.0      0      0  STON/O2. 3101282        S         1
# 4         3    male  35.0      0      0            373450        S         0
# 5         3    male  28.0      0      0            330877        Q         0
# ..      ...     ...   ...    ...    ...               ...      ...       ...
# 880       2    male  27.0      0      0            211536        S         0
# 881       1  female  19.0      0      0            112053        S         1
# 882       3  female  28.0      1      2        W./C. 6607        S         0
# 883       1    male  26.0      0      0            111369        C         1
# 884       3    male  32.0      0      0            370376        Q         0
#
#     ticket_date
# 0    1912-01-12
# ...

# %%
# 방법 2. 컬럼을 지정하고 싶을 때
# 하나의 컬럼만 사용하더라도 리스트 형태로 정의해야 함
titanic_df.dropna(subset = ['Embarked'])
# Out:
#      Pclass   Gendr   Age  SibSp  Parch            Ticket Embarked  Survived  \
# 0         3    male  22.0      1      0         A/5 21171        S         0
# 1         1  female  38.0      1      0          PC 17599        C         1
# 2         3  female  26.0      0      0  STON/O2. 3101282        S         1
# 3         1  female   NaN      1      0            113803        S         1
# 4         3    male  35.0      0      0            373450        S         0
# ..      ...     ...   ...    ...    ...               ...      ...       ...
# 880       2    male  27.0      0      0            211536        S         0
# 881       1  female  19.0      0      0            112053        S         1
# 882       3  female  28.0      1      2        W./C. 6607        S         0
# 883       1    male  26.0      0      0            111369        C         1
# 884       3    male  32.0      0      0            370376        Q         0
#
#     ticket_date
# 0    1912-01-12
# ...

# %% [markdown]
# 데이터가 많지 않은 경우에 결측치를 모두 제거하는 것은 좋지 않기 때문에,
# 해당 예제에서는 결측치를 채워줄 것이다.

# %%
titanic_df['Age'].mean()
# Out:
# 29.679180887372013

# %%
titanic_df['Age'].median()
# Out:
# 28.0

# %%
# 일반적으로 median을 사용한다.
# mean의 경우, outlier 때문에 값이 치우칠 여지가 있다.

titanic_df['Age'] = titanic_df['Age'].fillna(titanic_df['Age'].median())

# %%
titanic_df.loc[age_na_index]
# Out:
#      Pclass   Gendr   Age  SibSp  Parch           Ticket Embarked  Survived  \
# 3         1  female  28.0      1      0           113803        S         1
# 106       3    male  28.0      0      0           312991        S         1
# 156       3    male  28.0      0      0  SOTON/OQ 392090        S         0
# 185       3  female  28.0      1      0           370365        Q         1
# 213       3    male  28.0      1      0           367229        Q         0
# 241       2    male  28.0      0      0      W./C. 14263        S         0
#
#     ticket_date
# 3    1912-03-28
# 106  1912-01-27
# 156  1912-04-01
# 185  1912-03-25
# 213  1912-02-12
# 241  1912-01-31

# %%
# 카테고리형 데이터의 결측치는 평균을 구할 수 없다.

# 방법 1. 특정 값이 다수의 역할을 하고 있을 때 (99% 값이 S인 경우)
titanic_df['Embarked'].value_counts()
# Out:
# S    640
# C    166
# Q     77
# Name: Embarked, dtype: int64

# %%
640 / 885
# 해당 예제에서는 약 72%로 방법 1이 최선은 아닐 수 있다.
# Out:
# 0.7231638418079096

# %%
# 방법 2. null값임을 정의해주는 별도의 값으로 채우기
# unknown, N/A 등

titanic_df['Embarked'].fillna('N/A')

# %%
# 해당 예제에서는 null값을 따로 정의해두는 게 큰 의미는 없을 것 같다.
# 따라서 72%의 확률을 믿고 채우기

titanic_df['Embarked'] = titanic_df['Embarked'].fillna('S')

# %% [markdown]
# 특정 컬럼에 결측치가 많은 경우(50%, 70% 이상 등) 컬럼 자체를 제거하는 것도 방법이다.

# %% [markdown]
# # 3. 이상치 탐지 및 처리 (Outliers)

# %%
titanic_df.describe()
# Out:
#            Pclass         Age       SibSp       Parch    Survived
# count  885.000000  885.000000  885.000000  885.000000  885.000000
# mean     2.311864   29.667797    0.525424    0.377401    0.377401
# std      0.836069   13.514272    1.109746    0.805768    0.485011
# min      1.000000    1.000000    0.000000    0.000000    0.000000
# 25%      2.000000   22.000000    0.000000    0.000000    0.000000
# 50%      3.000000   28.000000    0.000000    0.000000    0.000000
# 75%      3.000000   35.000000    1.000000    0.000000    1.000000
# max      3.000000  145.000000    8.000000    6.000000    1.000000

# %%
titanic_df['Age'].sort_values()
# titanic_df['Age'].sort_values(ascending = False)  # 내림차순 정렬
# Out:
# 163      1.0
# 823      1.0
# 379      1.0
# 384      1.0
# 785      1.0
#        ...
# 490     71.0
# 845     74.0
# 627     80.0
# 279     97.0
# 321    145.0
# Name: Age, Length: 885, dtype: float64

# %%
titanic_df['SibSp'].sort_values().tail(15)
# Out:
# 809    4
# 51     4
# 820    4
# 680    5
# 71     5
# 384    5
# 60     5
# 477    5
# 857    8
# 158    8
# 840    8
# 179    8
# 322    8
# 789    8
# 200    8
# Name: SibSp, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.displot(titanic_df['Age'])

# %%
sns.displot(titanic_df['SibSp'])

# %%
sns.scatterplot(x = titanic_df.index, y = titanic_df['Age'])
# Out:
# <AxesSubplot:ylabel='Age'>

# %%
sns.scatterplot(x = titanic_df.index, y = titanic_df['SibSp'])
# Out:
# <AxesSubplot:ylabel='SibSp'>

# %%
sns.boxplot(titanic_df['Age'])
# Out:
# /opt/conda/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age'>

# %% [markdown]
# 파란색 박스(IQR)는 25% ~ 75% 사이의 값을 나타낸다.
#
# ```
# IQR = 75% - 25%
# IQR * 1.5
# ```
#
# boxplot에서는 IQR * 1.5 범위를 넘어가면 outliers로 정의한다.
# -> 반드시 따라아햐는 정의가 아니다.
#
# ---

# %% [markdown]
# (심플한)머신러닝 모델에서 학습 데이터에 outliers가 들어감에 따라서 모델 계산이 한 쪽으로 편향될 수 있다.
#
# 학습 시 outliers가 끼어있으면 새로운 데이터를 예측할 때 잘못된 결과가 예측될 수 있다.
#
# => 학습 데이터셋의 특성, 나중에 사용될 데이터셋의 특성, 사용할 머신러닝 알고리즘의 복잡성을 모두 고려하여 이상치를 처리해야 한다.

# %%
titanic_df = titanic_df[titanic_df['Age'] <= 100]

# %%
titanic_df['Age'].sort_values()
# Out:
# 785     1.0
# 182     1.0
# 171     1.0
# 379     1.0
# 163     1.0
#        ...
# 95     71.0
# 490    71.0
# 845    74.0
# 627    80.0
# 279    97.0
# Name: Age, Length: 884, dtype: float64

# %%
def age_func(x):
  if x > 80:
    return 80
  else:
    return x

# %%
titanic_df['Age'] = titanic_df['Age'].apply(age_func)

# lambda 표현식 사용하기 (함수 정의 필요 X)
# titanic_df['Age'].apply(lambda x: 80 if x>80 else x)

# %%
titanic_df['Age'].sort_values()
# Out:
# 785     1.0
# 182     1.0
# 171     1.0
# 379     1.0
# 163     1.0
#        ...
# 95     71.0
# 490    71.0
# 845    74.0
# 279    80.0
# 627    80.0
# Name: Age, Length: 884, dtype: float64
